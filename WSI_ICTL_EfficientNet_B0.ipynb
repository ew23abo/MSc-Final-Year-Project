# %%
# !pip install --upgrade tensorflow tensorflow-datasets
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (19.0.1)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.16.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.3.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.69.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 1.4 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 63.0 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 105.1 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 107.0 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 110.5 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.5 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, wheel, werkzeug, tensorflow-io-gcs-filesystem, tensorboard-data-server, google-pasta, tensorboard, astunparse, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 google-pasta-0.2.0 libclang-18.1.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 werkzeug-3.1.3 wheel-0.45.1

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Enable memory growth for GPUs (avoid crashes)
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# Load PatchCamelyon dataset efficiently
(ds_train, ds_validation, ds_test), ds_info = tfds.load(
    'patch_camelyon',
    split=['train[:80%]', 'train[80%:]', 'validation'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# Verify loaded dataset
print(f"Dataset Info:\n{ds_info}")

# Example: view a sample image
import matplotlib.pyplot as plt

def show_sample(image, label):
    plt.imshow(image.numpy())
    plt.title(f"Label: {label.numpy()}")
    plt.axis('off')

for image, label in ds_train.take(1):
    show_sample(image, label)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/patch_camelyon/2.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/patch_camelyon/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/patch_camelyon/incomplete.IAZDME_2.0.0/patch_camelyon-test.tfrecord*...:  …
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/patch_camelyon/incomplete.IAZDME_2.0.0/patch_camelyon-train.tfrecord*...: …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/patch_camelyon/incomplete.IAZDME_2.0.0/patch_camelyon-validation.tfrecord*…
# Dataset patch_camelyon downloaded and prepared to /root/tensorflow_datasets/patch_camelyon/2.0.0. Subsequent calls will reuse this data.
# Dataset Info:
# tfds.core.DatasetInfo(
#     name='patch_camelyon',
#     full_name='patch_camelyon/2.0.0',
#     description="""
#     The PatchCamelyon benchmark is a new and challenging image classification
#     dataset. It consists of 327.680 color images (96 x 96px) extracted from
#     histopathologic scans of lymph node sections. Each image is annoted with a
#     binary label indicating presence of metastatic tissue. PCam provides a new
#     benchmark for machine learning models: bigger than CIFAR10, smaller than
#     Imagenet, trainable on a single GPU.
#     """,
#     homepage='https://patchcamelyon.grand-challenge.org/',
#     data_dir='/root/tensorflow_datasets/patch_camelyon/2.0.0',
#     file_format=tfrecord,
#     download_size=7.48 GiB,
#     dataset_size=7.06 GiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=string),
#         'image': Image(shape=(96, 96, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     nondeterministic_order=False,
#     splits={
#         'test': <SplitInfo num_examples=32768, num_shards=8>,
#         'train': <SplitInfo num_examples=262144, num_shards=64>,
#         'validation': <SplitInfo num_examples=32768, num_shards=8>,
#     },
#     citation="""@misc{b_s_veeling_j_linmans_j_winkens_t_cohen_2018_2546921,
#       author       = {B. S. Veeling, J. Linmans, J. Winkens, T. Cohen, M. Welling},
#       title        = {Rotation Equivariant CNNs for Digital Pathology},
#       month        = sep,
#       year         = 2018,
#       doi          = {10.1007/978-3-030-00934-2_24},
#       url          = {https://doi.org/10.1007/978-3-030-00934-2_24}
#     }""",
# )

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

# Load the dataset
ds_train, ds_info = tfds.load('patch_camelyon', split='train', with_info=True, as_supervised=True)

# Display 5 sample images with labels
plt.figure(figsize=(15, 3))
for i, (image, label) in enumerate(ds_train.take(5)):
    plt.subplot(1, 5, i + 1)
    plt.imshow(image.numpy())
    plt.title(f'Label: {label.numpy()}')
    plt.axis('off')

plt.show()

# %%
# Import necessary libraries
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# Enable GPU memory growth to avoid runtime crashes
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)

# Load PCam dataset with 80% train and 20% test split
(ds_train, ds_test), ds_info = tfds.load(
    'patch_camelyon',
    split=['train[:80%]', 'train[80%:]'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# Verify dataset info
print(ds_info)

# Define preprocessing and augmentation functions
def preprocess(image, label):
    # Normalize images to [0, 1]
    image = tf.image.convert_image_dtype(image, tf.float32)
    # Resize images to ensure consistent input size (if required by your models)
    image = tf.image.resize(image, [96, 96])
    return image, label

# Augmentation function according to PDM plan (rotation, flip, contrast)

def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    image = tf.clip_by_value(image, 0.0, 1.0)  # Ensure pixel values are within [0,1]
    return image, label

# Apply preprocessing, augmentation, batching, caching, and prefetching
batch_size = 64

# Training dataset pipeline
ds_train = (
    ds_train
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    .cache()
    .shuffle(1000)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

# Test dataset pipeline (no augmentation, just preprocessing)
ds_test = (
    ds_test
    .map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .cache()
    .prefetch(tf.data.AUTOTUNE)
)

# Check a batch of training images
for images, labels in ds_train.take(1):
    plt.figure(figsize=(15, 5))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        plt.imshow(images[i].numpy())
        plt.title(f'Label: {labels[i].numpy()}')
        plt.axis('off')
    plt.show()
# Out:
# tfds.core.DatasetInfo(
#     name='patch_camelyon',
#     full_name='patch_camelyon/2.0.0',
#     description="""
#     The PatchCamelyon benchmark is a new and challenging image classification
#     dataset. It consists of 327.680 color images (96 x 96px) extracted from
#     histopathologic scans of lymph node sections. Each image is annoted with a
#     binary label indicating presence of metastatic tissue. PCam provides a new
#     benchmark for machine learning models: bigger than CIFAR10, smaller than
#     Imagenet, trainable on a single GPU.
#     """,
#     homepage='https://patchcamelyon.grand-challenge.org/',
#     data_dir='/root/tensorflow_datasets/patch_camelyon/2.0.0',
#     file_format=tfrecord,
#     download_size=7.48 GiB,
#     dataset_size=7.06 GiB,
#     features=FeaturesDict({
#         'id': Text(shape=(), dtype=string),
#         'image': Image(shape=(96, 96, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     nondeterministic_order=False,
#     splits={
#         'test': <SplitInfo num_examples=32768, num_shards=8>,
#         'train': <SplitInfo num_examples=262144, num_shards=64>,
#         'validation': <SplitInfo num_examples=32768, num_shards=8>,
#     },
#     citation="""@misc{b_s_veeling_j_linmans_j_winkens_t_cohen_2018_2546921,
#       author       = {B. S. Veeling, J. Linmans, J. Winkens, T. Cohen, M. Welling},
#       title        = {Rotation Equivariant CNNs for Digital Pathology},
#       month        = sep,
#       year         = 2018,
#       doi          = {10.1007/978-3-030-00934-2_24},
#       url          = {https://doi.org/10.1007/978-3-030-00934-2_24}
#     }""",
# )

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# Load EfficientNet-B0 model pre-trained on ImageNet, exclude top layers
base_model = EfficientNetB0(input_shape=(96, 96, 3), include_top=False, weights='imagenet')

# Freeze base model layers
base_model.trainable = False

# Create model structure
model_efficientnet = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile the model
model_efficientnet.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# Model summary
model_efficientnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 3, 3, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │           1,281 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,050,852 (15.45 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
# Train EfficientNet-B0 model for 20 epochs
history_efficientnet = model_efficientnet.fit(
    ds_train,
    epochs=20,
    validation_data=ds_test
)
# Out:
# Epoch 1/20
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 583s 178ms/step - accuracy: 0.5457 - auc: 0.5575 - loss: 0.6846 - val_accuracy: 0.5849 - val_auc: 0.5611 - val_loss: 0.6777

# %%
# Unfreeze the base model
base_model.trainable = True

# Recompile with lower learning rate
model_efficientnet.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

# Fine-tune the model for 10 additional epochs
history_finetune_efficientnet = model_efficientnet.fit(
    ds_train,
    epochs=10,
    validation_data=ds_test
)
# Out:
# Epoch 1/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1844s 550ms/step - accuracy: 0.7029 - auc: 0.7688 - loss: 0.9528 - val_accuracy: 0.7955 - val_auc: 0.8803 - val_loss: 0.4920
# Epoch 2/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1744s 532ms/step - accuracy: 0.7980 - auc: 0.8804 - loss: 0.4834 - val_accuracy: 0.8281 - val_auc: 0.9167 - val_loss: 0.3994
# Epoch 3/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1732s 528ms/step - accuracy: 0.8363 - auc: 0.9164 - loss: 0.3790 - val_accuracy: 0.8613 - val_auc: 0.9394 - val_loss: 0.3268
# Epoch 4/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1714s 523ms/step - accuracy: 0.8660 - auc: 0.9386 - loss: 0.3190 - val_accuracy: 0.8662 - val_auc: 0.9478 - val_loss: 0.3176
# Epoch 5/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1710s 522ms/step - accuracy: 0.8837 - auc: 0.9517 - loss: 0.2811 - val_accuracy: 0.8972 - val_auc: 0.9619 - val_loss: 0.2496
# Epoch 6/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1721s 525ms/step - accuracy: 0.8975 - auc: 0.9612 - loss: 0.2513 - val_accuracy: 0.9082 - val_auc: 0.9685 - val_loss: 0.2259
# Epoch 7/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1726s 527ms/step - accuracy: 0.9072 - auc: 0.9671 - loss: 0.2306 - val_accuracy: 0.9081 - val_auc: 0.9699 - val_loss: 0.2286
# Epoch 8/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1729s 528ms/step - accuracy: 0.9146 - auc: 0.9722 - loss: 0.2116 - val_accuracy: 0.9069 - val_auc: 0.9710 - val_loss: 0.2308
# Epoch 9/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1734s 529ms/step - accuracy: 0.9220 - auc: 0.9758 - loss: 0.1967 - val_accuracy: 0.9223 - val_auc: 0.9754 - val_loss: 0.1990
# Epoch 10/10
# 3277/3277 ━━━━━━━━━━━━━━━━━━━━ 1744s 532ms/step - accuracy: 0.9279 - auc: 0.9792 - loss: 0.1822 - val_accuracy: 0.9228 - val_auc: 0.9771 - val_loss: 0.1964

# %%
# Required imports
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Plot training curves function
def plot_training_curves(history):
    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(history.history['accuracy'], label='Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 3, 2)
    plt.plot(history.history['loss'], label='Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 3, 3)
    plt.plot(history.history['auc'], label='AUC')
    plt.plot(history.history['val_auc'], label='Validation AUC')
    plt.title('AUC-ROC')
    plt.xlabel('Epoch')
    plt.ylabel('AUC')
    plt.legend()

    plt.show()

# Evaluate model function
def evaluate_model(model, dataset):
    y_true, y_pred = [], []
    for images, labels in dataset:
        predictions = model.predict(images)
        predictions = np.round(predictions).astype(int)
        y_true.extend(labels.numpy())
        y_pred.extend(predictions.flatten())

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)

    print("\nEfficientNet-B0 Model Evaluation Metrics:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"AUC-ROC: {auc:.4f}")

# Run these after fine-tuning
plot_training_curves(history_finetune_efficientnet)
evaluate_model(model_efficientnet, ds_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# EfficientNet-B0 Model Evaluation Metrics:
# Accuracy: 0.9228
# Precision: 0.9117
# Recall: 0.9361
# F1 Score: 0.9238
# AUC-ROC: 0.9228
